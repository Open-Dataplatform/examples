# %% [markdown]
# # DMI

# %% [markdown]
# ### Installation
# Run the following cell to install osiris-sdk.

# %%
# !pip install osiris-sdk

# %% [markdown]
# ### Config file
# he configuration is advised to be done in a file.
#
# The structure of **conf.ini**:
# ```
# [Authorization]
# tenant_id = <tenant_id>
# client_id = <client_id>
# client_secret = <client_secret>
#
# [Egress]
# url = <egress-url>
# ```

# %% [markdown]
# ### Imports
# Execute the following cell to import the necessary libraries

# %%
import pandas as pd
from io import BytesIO
from osiris.apis.egress import Egress
from osiris.core.azure_client_authorization import ClientAuthorization
from configparser import ConfigParser

# %% [markdown]
# ### List all DMI stations for a given month
# To list all the available stations for a given month run the following code.
#
# Feel free to change the month using the format: YYYY-MM

# %%
config = ConfigParser()
config.read('conf.ini')

client_auth = ClientAuthorization(tenant_id=config['Authorization']['tenant_id'],
                                  client_id=config['Authorization']['client_id'],
                                  client_secret=config['Authorization']['client_secret'])

egress = Egress(client_auth=client_auth,
                egress_url=config['Egress']['url'])

egress.download_dmi_list('2021-01')
# Out:
# [{'lon': 15.19, 'lat': 55.0},
#  {'lon': 15.28, 'lat': 55.14},
#  {'lon': 14.85, 'lat': 54.92},
#  {'lon': 14.94, 'lat': 55.06},
#  {'lon': 15.03, 'lat': 55.19},
#  {'lon': 14.61, 'lat': 54.97},
#  {'lon': 14.7, 'lat': 55.11},
#  {'lon': 14.79, 'lat': 55.25},
#  {'lon': 14.27, 'lat': 54.89},
#  {'lon': 14.36, 'lat': 55.03},
#  {'lon': 14.45, 'lat': 55.16},
#  {'lon': 14.54, 'lat': 55.3},
#  {'lon': 14.03, 'lat': 54.94},
#  {'lon': 14.12, 'lat': 55.08},
#  {'lon': 13.12, 'lat': 54.82},
#  {'lon': 13.21, 'lat': 54.95},
#  {'lon': 12.88, 'lat': 54.87},
#  {'lon': 12.96, 'lat': 55.0},
#  {'lon': 12.63, 'lat': 54.91},
#  {'lon': 12.71, 'lat': 55.05},
#  {'lon': 12.79, 'lat': 55.19},
#  {'lon': 12.14, 'lat': 54.55},
#  {'lon': 12.22, 'lat': 54.68},
#  {'lon': 12.3, 'lat': 54.82},
#  {'lon': 12.38, 'lat': 54.96},
#  {'lon': 12.46, 'lat': 55.1},
#  {'lon': 12.55, 'lat': 55.24},
#  {'lon': 12.63, 'lat': 55.38},
#  {'lon': 12.71, 'lat': 55.52},
#  {'lon': 12.8, 'lat': 55.65},
#  {'lon': 11.82, 'lat': 54.45},
#  {'lon': 11.89, 'lat': 54.59},
#  {'lon': 11.97, 'lat': 54.73},
#  {'lon': 12.05, 'lat': 54.87},
#  {'lon': 12.13, 'lat': 55.01},
#  {'lon': 12.21, 'lat': 55.15},
#  {'lon': 12.3, 'lat': 55.29},
#  {'lon': 12.38, 'lat': 55.43},
#  {'lon': 12.46, 'lat': 55.57},
#  {'lon': 12.55, 'lat': 55.7},
#  {'lon': 12.63, 'lat': 55.84},
#  {'lon': 12.72, 'lat': 55.98},
#  {'lon': 11.57, 'lat': 54.5},
#  {'lon': 11.65, 'lat': 54.64},
#  {'lon': 11.73, 'lat': 54.78},
#  {'lon': 11.81, 'lat': 54.92},
#  {'lon': 11.88, 'lat': 55.06},
#  {'lon': 11.97, 'lat': 55.2},
#  {'lon': 12.05, 'lat': 55.34},
#  {'lon': 12.13, 'lat': 55.47},
#  {'lon': 12.21, 'lat': 55.61},
#  {'lon': 12.29, 'lat': 55.75},
#  {'lon': 12.38, 'lat': 55.89},
#  {'lon': 12.46, 'lat': 56.03},
#  {'lon': 12.55, 'lat': 56.17},
#  {'lon': 11.32, 'lat': 54.55},
#  {'lon': 11.4, 'lat': 54.69},
#  {'lon': 11.48, 'lat': 54.82},
#  {'lon': 11.56, 'lat': 54.96},
#  {'lon': 11.64, 'lat': 55.1},
#  {'lon': 11.72, 'lat': 55.24},
#  {'lon': 11.8, 'lat': 55.38},
#  {'lon': 11.88, 'lat': 55.52},
#  {'lon': 11.96, 'lat': 55.66},
#  {'lon': 12.04, 'lat': 55.8},
#  {'lon': 12.12, 'lat': 55.94},
#  {'lon': 12.21, 'lat': 56.08},
#  {'lon': 12.29, 'lat': 56.22},
#  {'lon': 11.08, 'lat': 54.59},
#  {'lon': 11.15, 'lat': 54.73},
#  {'lon': 11.23, 'lat': 54.87},
#  {'lon': 11.31, 'lat': 55.01},
#  {'lon': 11.39, 'lat': 55.15},
#  {'lon': 11.47, 'lat': 55.29},
#  {'lon': 11.54, 'lat': 55.43},
#  {'lon': 11.62, 'lat': 55.57},
#  {'lon': 11.71, 'lat': 55.71},
#  {'lon': 11.79, 'lat': 55.85},
#  {'lon': 11.87, 'lat': 55.99},
#  {'lon': 11.95, 'lat': 56.13},
#  {'lon': 12.04, 'lat': 56.26},
#  {'lon': 12.12, 'lat': 56.4},
#  {'lon': 12.21, 'lat': 56.54},
#  {'lon': 10.83, 'lat': 54.64},
#  {'lon': 10.91, 'lat': 54.78},
#  {'lon': 10.98, 'lat': 54.92},
#  {'lon': 11.06, 'lat': 55.06},
#  {'lon': 11.14, 'lat': 55.2},
#  {'lon': 11.21, 'lat': 55.34},
#  {'lon': 11.29, 'lat': 55.48},
#  {'lon': 11.37, 'lat': 55.62},
#  {'lon': 11.45, 'lat': 55.75},
#  {'lon': 11.53, 'lat': 55.89},
#  {'lon': 11.62, 'lat': 56.03},
#  {'lon': 11.86, 'lat': 56.45},
#  {'lon': 11.95, 'lat': 56.59},
#  {'lon': 10.58, 'lat': 54.68},
#  {'lon': 10.66, 'lat': 54.82},
#  {'lon': 10.73, 'lat': 54.96},
#  {'lon': 10.81, 'lat': 55.1},
#  {'lon': 10.89, 'lat': 55.24},
#  {'lon': 10.96, 'lat': 55.38},
#  {'lon': 11.04, 'lat': 55.52},
#  {'lon': 11.12, 'lat': 55.66},
#  {'lon': 11.2, 'lat': 55.8},
#  {'lon': 11.28, 'lat': 55.94},
#  {'lon': 11.36, 'lat': 56.08},
#  {'lon': 10.33, 'lat': 54.72},
#  {'lon': 10.41, 'lat': 54.86},
#  {'lon': 10.48, 'lat': 55.0},
#  {'lon': 10.56, 'lat': 55.14},
#  {'lon': 10.63, 'lat': 55.29},
#  {'lon': 10.71, 'lat': 55.43},
#  {'lon': 10.79, 'lat': 55.57},
#  {'lon': 10.87, 'lat': 55.71},
#  {'lon': 10.94, 'lat': 55.85},
#  {'lon': 11.02, 'lat': 55.99},
#  {'lon': 11.1, 'lat': 56.13},
#  {'lon': 11.35, 'lat': 56.55},
#  {'lon': 11.43, 'lat': 56.69},
#  {'lon': 10.09, 'lat': 54.77},
#  {'lon': 10.16, 'lat': 54.91},
#  {'lon': 10.23, 'lat': 55.05},
#  {'lon': 10.31, 'lat': 55.19},
#  {'lon': 10.38, 'lat': 55.33},
#  {'lon': 10.46, 'lat': 55.47},
#  {'lon': 10.53, 'lat': 55.61},
#  {'lon': 10.61, 'lat': 55.75},
#  {'lon': 10.69, 'lat': 55.89},
#  {'lon': 10.77, 'lat': 56.03},
#  {'lon': 10.85, 'lat': 56.17},
#  {'lon': 10.93, 'lat': 56.31},
#  {'lon': 11.01, 'lat': 56.45},
#  {'lon': 11.09, 'lat': 56.59},
#  {'lon': 11.17, 'lat': 56.73},
#  {'lon': 9.84, 'lat': 54.81},
#  {'lon': 9.91, 'lat': 54.95},
#  {'lon': 9.98, 'lat': 55.09},
#  {'lon': 10.06, 'lat': 55.23},
#  {'lon': 10.13, 'lat': 55.37},
#  {'lon': 10.2, 'lat': 55.51},
#  {'lon': 10.28, 'lat': 55.65},
#  {'lon': 10.36, 'lat': 55.8},
#  {'lon': 10.43, 'lat': 55.94},
#  {'lon': 10.51, 'lat': 56.08},
#  {'lon': 10.59, 'lat': 56.22},
#  {'lon': 10.67, 'lat': 56.36},
#  {'lon': 10.75, 'lat': 56.5},
#  {'lon': 10.83, 'lat': 56.64},
#  {'lon': 11.16, 'lat': 57.2},
#  {'lon': 11.24, 'lat': 57.34},
#  {'lon': 9.51, 'lat': 54.71},
#  {'lon': 9.59, 'lat': 54.85},
#  {'lon': 9.66, 'lat': 54.99},
#  {'lon': 9.73, 'lat': 55.13},
#  {'lon': 9.8, 'lat': 55.28},
#  {'lon': 9.88, 'lat': 55.42},
#  {'lon': 9.95, 'lat': 55.56},
#  {'lon': 10.03, 'lat': 55.7},
#  {'lon': 10.1, 'lat': 55.84},
#  {'lon': 10.18, 'lat': 55.98},
#  {'lon': 10.25, 'lat': 56.12},
#  {'lon': 10.33, 'lat': 56.26},
#  {'lon': 10.41, 'lat': 56.4},
#  {'lon': 10.49, 'lat': 56.54},
#  {'lon': 10.57, 'lat': 56.68},
#  {'lon': 10.65, 'lat': 56.82},
#  {'lon': 10.73, 'lat': 56.96},
#  {'lon': 10.81, 'lat': 57.1},
#  {'lon': 10.9, 'lat': 57.24},
#  {'lon': 10.98, 'lat': 57.38},
#  {'lon': 11.06, 'lat': 57.52},
#  {'lon': 9.26, 'lat': 54.75},
#  {'lon': 9.34, 'lat': 54.89},
#  {'lon': 9.41, 'lat': 55.03},
#  {'lon': 9.48, 'lat': 55.18},
#  {'lon': 9.55, 'lat': 55.32},
#  {'lon': 9.62, 'lat': 55.46},
#  {'lon': 9.7, 'lat': 55.6},
#  {'lon': 9.77, 'lat': 55.74},
#  {'lon': 9.85, 'lat': 55.88},
#  {'lon': 9.92, 'lat': 56.02},
#  {'lon': 10.0, 'lat': 56.16},
#  {'lon': 10.07, 'lat': 56.31},
#  {'lon': 10.15, 'lat': 56.45},
#  {'lon': 10.23, 'lat': 56.59},
#  {'lon': 10.31, 'lat': 56.73},
#  {'lon': 10.39, 'lat': 56.87},
#  {'lon': 10.47, 'lat': 57.01},
#  {'lon': 10.55, 'lat': 57.15},
#  {'lon': 10.63, 'lat': 57.29},
#  {'lon': 10.71, 'lat': 57.43},
#  {'lon': 10.8, 'lat': 57.57},
#  {'lon': 10.88, 'lat': 57.71},
#  {'lon': 9.01, 'lat': 54.79},
#  {'lon': 9.08, 'lat': 54.93},
#  {'lon': 9.15, 'lat': 55.08},
#  {'lon': 9.23, 'lat': 55.22},
#  {'lon': 9.3, 'lat': 55.36},
#  {'lon': 9.37, 'lat': 55.5},
#  {'lon': 9.44, 'lat': 55.64},
#  {'lon': 9.51, 'lat': 55.78},
#  {'lon': 9.59, 'lat': 55.92},
#  {'lon': 9.66, 'lat': 56.07},
#  {'lon': 9.74, 'lat': 56.21},
#  {'lon': 9.82, 'lat': 56.35},
#  {'lon': 9.89, 'lat': 56.49},
#  {'lon': 9.97, 'lat': 56.63},
#  {'lon': 10.05, 'lat': 56.77},
#  {'lon': 10.13, 'lat': 56.91},
#  {'lon': 10.21, 'lat': 57.05},
#  {'lon': 10.29, 'lat': 57.19},
#  {'lon': 10.37, 'lat': 57.33},
#  {'lon': 10.45, 'lat': 57.48},
#  {'lon': 10.53, 'lat': 57.62},
#  {'lon': 10.61, 'lat': 57.76},
#  {'lon': 10.7, 'lat': 57.9},
#  {'lon': 8.76, 'lat': 54.83},
#  {'lon': 8.83, 'lat': 54.97},
#  {'lon': 8.9, 'lat': 55.12},
#  {'lon': 8.97, 'lat': 55.26},
#  {'lon': 9.04, 'lat': 55.4},
#  {'lon': 9.11, 'lat': 55.54},
#  {'lon': 9.19, 'lat': 55.68},
#  {'lon': 9.26, 'lat': 55.83},
#  {'lon': 9.33, 'lat': 55.97},
#  {'lon': 9.41, 'lat': 56.11},
#  {'lon': 9.48, 'lat': 56.25},
#  {'lon': 9.56, 'lat': 56.39},
#  {'lon': 9.63, 'lat': 56.53},
#  {'lon': 9.71, 'lat': 56.67},
#  {'lon': 9.79, 'lat': 56.82},
#  {'lon': 9.86, 'lat': 56.96},
#  {'lon': 9.94, 'lat': 57.1},
#  {'lon': 10.02, 'lat': 57.24},
#  {'lon': 10.1, 'lat': 57.38},
#  {'lon': 10.18, 'lat': 57.52},
#  {'lon': 10.26, 'lat': 57.66},
#  {'lon': 10.35, 'lat': 57.8},
#  {'lon': 8.51, 'lat': 54.87},
#  {'lon': 8.58, 'lat': 55.01},
#  {'lon': 8.65, 'lat': 55.16},
#  {'lon': 8.72, 'lat': 55.3},
#  {'lon': 8.79, 'lat': 55.44},
#  {'lon': 8.86, 'lat': 55.58},
#  {'lon': 8.93, 'lat': 55.73},
#  {'lon': 9.0, 'lat': 55.87},
#  {'lon': 9.07, 'lat': 56.01},
#  {'lon': 9.15, 'lat': 56.15},
#  {'lon': 9.22, 'lat': 56.29},
#  {'lon': 9.3, 'lat': 56.43},
#  {'lon': 9.37, 'lat': 56.58},
#  {'lon': 9.45, 'lat': 56.72},
#  {'lon': 9.52, 'lat': 56.86},
#  {'lon': 9.6, 'lat': 57.0},
#  {'lon': 9.68, 'lat': 57.14},
#  {'lon': 9.76, 'lat': 57.28},
#  {'lon': 9.84, 'lat': 57.42},
#  {'lon': 9.92, 'lat': 57.56},
#  {'lon': 10.0, 'lat': 57.71},
#  {'lon': 8.26, 'lat': 54.91},
#  {'lon': 8.33, 'lat': 55.05},
#  {'lon': 8.4, 'lat': 55.2},
#  {'lon': 8.46, 'lat': 55.34},
#  {'lon': 8.53, 'lat': 55.48},
#  {'lon': 8.6, 'lat': 55.62},
#  {'lon': 8.67, 'lat': 55.77},
#  {'lon': 8.74, 'lat': 55.91},
#  {'lon': 8.82, 'lat': 56.05},
#  {'lon': 8.89, 'lat': 56.19},
#  {'lon': 8.96, 'lat': 56.33},
#  {'lon': 9.03, 'lat': 56.48},
#  {'lon': 9.11, 'lat': 56.62},
#  {'lon': 9.18, 'lat': 56.76},
#  {'lon': 9.26, 'lat': 56.9},
#  {'lon': 9.34, 'lat': 57.04},
#  {'lon': 9.41, 'lat': 57.18},
#  {'lon': 9.49, 'lat': 57.33},
#  {'lon': 9.57, 'lat': 57.47},
#  {'lon': 9.65, 'lat': 57.61},
#  {'lon': 8.14, 'lat': 55.24},
#  {'lon': 8.21, 'lat': 55.38},
#  {'lon': 8.28, 'lat': 55.52},
#  {'lon': 8.35, 'lat': 55.66},
#  {'lon': 8.42, 'lat': 55.81},
#  {'lon': 8.49, 'lat': 55.95},
#  {'lon': 8.56, 'lat': 56.09},
#  {'lon': 8.63, 'lat': 56.23},
#  {'lon': 8.7, 'lat': 56.37},
#  {'lon': 8.77, 'lat': 56.52},
#  {'lon': 8.85, 'lat': 56.66},
#  {'lon': 8.92, 'lat': 56.8},
#  {'lon': 9.0, 'lat': 56.94},
#  {'lon': 9.07, 'lat': 57.08},
#  {'lon': 9.15, 'lat': 57.23},
#  {'lon': 9.22, 'lat': 57.37},
#  {'lon': 9.3, 'lat': 57.51},
#  {'lon': 9.38, 'lat': 57.65},
#  {'lon': 7.89, 'lat': 55.27},
#  {'lon': 7.96, 'lat': 55.42},
#  {'lon': 8.02, 'lat': 55.56},
#  {'lon': 8.09, 'lat': 55.7},
#  {'lon': 8.16, 'lat': 55.85},
#  {'lon': 8.23, 'lat': 55.99},
#  {'lon': 8.3, 'lat': 56.13},
#  {'lon': 8.37, 'lat': 56.27},
#  {'lon': 8.44, 'lat': 56.42},
#  {'lon': 8.51, 'lat': 56.56},
#  {'lon': 8.58, 'lat': 56.7},
#  {'lon': 8.66, 'lat': 56.84},
#  {'lon': 8.73, 'lat': 56.98},
#  {'lon': 8.81, 'lat': 57.13},
#  {'lon': 8.88, 'lat': 57.27},
#  {'lon': 8.96, 'lat': 57.41},
#  {'lon': 9.03, 'lat': 57.55},
#  {'lon': 9.11, 'lat': 57.69},
#  {'lon': 7.63, 'lat': 55.31},
#  {'lon': 7.7, 'lat': 55.46},
#  {'lon': 7.77, 'lat': 55.6},
#  {'lon': 7.83, 'lat': 55.74},
#  {'lon': 7.9, 'lat': 55.88},
#  {'lon': 7.97, 'lat': 56.03},
#  {'lon': 8.04, 'lat': 56.17},
#  {'lon': 8.11, 'lat': 56.31},
#  {'lon': 8.18, 'lat': 56.45},
#  {'lon': 8.25, 'lat': 56.6},
#  {'lon': 8.32, 'lat': 56.74},
#  {'lon': 8.39, 'lat': 56.88},
#  {'lon': 8.47, 'lat': 57.02},
#  {'lon': 8.54, 'lat': 57.17},
#  {'lon': 8.61, 'lat': 57.31},
#  {'lon': 8.69, 'lat': 57.45},
#  {'lon': 8.76, 'lat': 57.59},
#  {'lon': 8.84, 'lat': 57.74},
#  {'lon': 7.38, 'lat': 55.35},
#  {'lon': 7.44, 'lat': 55.49},
#  {'lon': 7.51, 'lat': 55.64},
#  {'lon': 7.58, 'lat': 55.78},
#  {'lon': 7.64, 'lat': 55.92},
#  {'lon': 7.71, 'lat': 56.07},
#  {'lon': 7.78, 'lat': 56.21},
#  {'lon': 7.85, 'lat': 56.35},
#  {'lon': 7.92, 'lat': 56.49},
#  {'lon': 7.99, 'lat': 56.64},
#  {'lon': 8.06, 'lat': 56.78},
#  {'lon': 8.13, 'lat': 56.92},
#  {'lon': 8.2, 'lat': 57.06},
#  {'lon': 7.25, 'lat': 55.67},
#  {'lon': 7.32, 'lat': 55.82},
#  {'lon': 7.38, 'lat': 55.96},
#  {'lon': 7.45, 'lat': 56.1},
#  {'lon': 7.52, 'lat': 56.25},
#  {'lon': 7.58, 'lat': 56.39},
#  {'lon': 7.65, 'lat': 56.53}]

# %% [markdown]
# ### Download DMI data for a given station and time period
# To download the data for a given station (lon, lat) for a time period (from_date, to_date) execute the following cell.
#
# You can find the available values of **lon** and **lat** from the previous call.

# %%
parquet_content = egress.download_dmi_file(lon=15.19, 
                                           lat=55.00, 
                                           from_date='2021-01', 
                                           to_date='2021-03')

pd.read_parquet(BytesIO(parquet_content))
# Out:
#           lon   lat  value         weather_type     model  predicted_ahead  \
# 0       15.19  55.0  277.7        temperatur_2m  harmonie                0
# 1       15.19  55.0  277.5        temperatur_2m  harmonie                1
# 2       15.19  55.0  277.4        temperatur_2m  harmonie                2
# 3       15.19  55.0  277.1        temperatur_2m  harmonie                3
# 4       15.19  55.0  276.8        temperatur_2m  harmonie                4
# ...       ...   ...    ...                  ...       ...              ...
# 206137  15.19  55.0  325.0  wind_direction_100m  harmonie                2
# 206190  15.19  55.0    0.0         radiation_ny  harmonie                0
# 206191  15.19  55.0    0.0         radiation_ny  harmonie                1
# 206244  15.19  55.0    0.0       radiation_hour  harmonie                0
# 206245  15.19  55.0    0.0       radiation_hour  harmonie                1
#
#                             Date          _dp_datetime_utc
# 0      2021-01-01 00:00:00+00:00 2021-01-01 00:00:00+00:00
# 1      2021-01-01 01:00:00+00:00 2021-01-01 01:00:00+00:00
# 2      2021-01-01 02:00:00+00:00 2021-01-01 02:00:00+00:00
# 3      2021-01-01 03:00:00+00:00 2021-01-01 03:00:00+00:00
# 4      2021-01-01 04:00:00+00:00 2021-01-01 04:00:00+00:00
# ...                          ...                       ...
# 206137 2021-02-28 23:00:00+00:00 2021-02-28 23:00:00+00:00
# 206190 2021-02-28 22:00:00+00:00 2021-02-28 22:00:00+00:00
# 206191 2021-02-28 23:00:00+00:00 2021-02-28 23:00:00+00:00
# 206244 2021-02-28 22:00:00+00:00 2021-02-28 22:00:00+00:00
# 206245 2021-02-28 23:00:00+00:00 2021-02-28 23:00:00+00:00
#
# [202482 rows x 8 columns]
